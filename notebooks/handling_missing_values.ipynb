# %% [markdown]
# # Handling Missing Values
#
# In this notebook, we will explore various techniques for identifying and handling missing values in datasets. Missing values can significantly impact the performance of machine learning models, so it is crucial to address them appropriately.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualisation style
sns.set(style='whitegrid')

# %%
# Load the dataset
data = pd.read_csv('../datasets/red_wine.csv')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.00         0.00             1.0      0.092
# 3           11.2              0.28         0.47             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Summary of missing values
missing_values = data.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## Visualizing Missing Values
# We can visualize the missing values using a heatmap.

# %%
# Visualize missing values
plt.figure(figsize=(10, 6))
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# ## Handling Missing Values
# There are several strategies to handle missing values:
# 1. **Drop missing values**
# 2. **Fill missing values with mean/median/mode**
# 3. **Use interpolation**
# 4. **Predict missing values using machine learning models**
#
# Let's explore these methods.

# %%
# Drop rows with missing values
data_dropped = data.dropna()
data_dropped.shape
# Out:
# (10, 12)

# %%
# Fill missing values with mean
data_filled = data.fillna(data.mean())
data_filled.isnull().sum().sum()  # Check if there are any missing values left
# Out:
# 0

# %% [markdown]
# ## Conclusion
# In this notebook, we have covered various techniques for identifying and handling missing values in datasets. It is essential to choose the right method based on the context and nature of the data.
